# %% [markdown]
# # EDA - Used Car Resale Price
#
#
# This notebook introduces the pandas library for data loading and prepartation and explores techniques of Exploratory Data Analysis (EDA).
#
# ## Dataset
#
# **Filename**: used_cars_maruti.csv
#
# It is a comma separated file and there are 11 columns in the dataset.
#
# 1. Model - Model of the car
# 2. Location - The location in which the car was sold.
# 3. Age - Age of the car when the car was sold from the year of purchase.
# 4. KM_Driven - The total kilometers are driven in the car by the previous owner(s) in '000 kms.
# 5. Fuel_Type - The type of fuel used by the car. (Petrol, Diesel, Electric, CNG, LPG)
# 6. Transmission - The type of transmission used by the car. (Automatic / Manual)
# 7. Owner_Type - First, Second, Third, or Fourth & Above
# 8. Mileage - The standard mileage offered by the car company in kmpl or km/kg
# 9. Power - The maximum power of the engine in bhp.
# 10. Seats - The number of seats in the car.
# 11. Price - The resale price of the car (target).

# %% [markdown]
# ## 1. Loading the dataset

# %%
import pandas as pd
import numpy as np
import openpyxl

# %% [markdown]
# ### Check Library Versions

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
np.__version__
# Out:
# '1.21.5'

# %%
cars_df = pd.read_csv('used_cars_maruti.csv')

# %% [markdown]
# ### Showing few records

# %%
cars_df.head(5)
# Out:
#     Location Fuel_Type Transmission Owner_Type  Seats  Price  Age   Model  \
# 0    Chennai    Diesel       Manual      First      7   6.00    8  ertiga
# 1     Jaipur    Diesel       Manual      First      5   5.60    5   swift
# 2     Jaipur    Diesel       Manual      First      5   5.99    3   swift
# 3  Hyderabad    Petrol       Manual     Second      5   2.75    7    alto
# 4     Jaipur    Petrol       Manual     Second      5   1.85   11   wagon
#
#    Mileage  Power  KM_Driven
# 0    20.77  88.76         87
# 1    25.20  74.00         64
# 2    28.40  74.00         25
# 3    20.92  67.10         54
# 4    14.00  64.00         83

# %% [markdown]
# ## Getting metadata

# %%
cars_df.shape
# Out:
# (1070, 11)

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Location      1070 non-null   object
#  1   Fuel_Type     1070 non-null   object
#  2   Transmission  1070 non-null   object
#  3   Owner_Type    1070 non-null   object
#  4   Seats         1070 non-null   int64
#  5   Price         1070 non-null   float64
#  6   Age           1070 non-null   int64
#  7   Model         1070 non-null   object
#  8   Mileage       1070 non-null   float64
#  9   Power         1070 non-null   float64
#  10  KM_Driven     1070 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 92.1+ KB

# %%
cars_df.info
# Out:
# <bound method DataFrame.info of        Location Fuel_Type Transmission Owner_Type  Seats  Price  Age    Model  \
# 0       Chennai    Diesel       Manual      First      7   6.00    8   ertiga
# 1        Jaipur    Diesel       Manual      First      5   5.60    5    swift
# 2        Jaipur    Diesel       Manual      First      5   5.99    3    swift
# 3     Hyderabad    Petrol       Manual     Second      5   2.75    7     alto
# 4        Jaipur    Petrol       Manual     Second      5   1.85   11    wagon
# ...         ...       ...          ...        ...    ...    ...  ...      ...
# 1065  Bangalore    Petrol       Manual      First      5   4.00    5  celerio
# 1066       Pune    Diesel       Manual      First      5   7.43    4   vitara
# 1067      Delhi    Diesel       Manual      First      5   2.75    9    swift
# 1068      Delhi    Diesel       Manual      First      5   4.75    6    swift
# 1069    Kolkata    Petrol       Manual      First      5   2.65    7    wagon
#
#       Mileage  Power  KM_Driven
# 0       20.77  88.76         87
# 1       25.20  74.00         64
# 2       28.40  74.00         25
# 3       20.92  67.10         54
# 4       14.00  64.00         83
# ...       ...    ...        ...
# 1065    23.10  67.04         67
# 1066    24.30  88.50         37
# 1067    19.30  73.90         68
# 1068    28.40  74.00         27
# 1069    18.90  67.10         46
#
# [1070 rows x 11 columns]>

# %% [markdown]
# ## 2. Indexing and Slicing
#
# Selecting specific set of rows and columns: How to slice, dice, and generally get and set subsets of pandas objects.
#
# Detailed Tutorial: https://pandas.pydata.org/pandas-docs/dev/user_guide/indexing.html

# %%
cars_df[0:5]
# Out:
#     Location Fuel_Type Transmission Owner_Type  Seats  Price  Age   Model  \
# 0    Chennai    Diesel       Manual      First      7   6.00    8  ertiga
# 1     Jaipur    Diesel       Manual      First      5   5.60    5   swift
# 2     Jaipur    Diesel       Manual      First      5   5.99    3   swift
# 3  Hyderabad    Petrol       Manual     Second      5   2.75    7    alto
# 4     Jaipur    Petrol       Manual     Second      5   1.85   11   wagon
#
#    Mileage  Power  KM_Driven
# 0    20.77  88.76         87
# 1    25.20  74.00         64
# 2    28.40  74.00         25
# 3    20.92  67.10         54
# 4    14.00  64.00         83

# %%
cars_df[-5:]
# Out:
#        Location Fuel_Type Transmission Owner_Type  Seats  Price  Age    Model  \
# 1065  Bangalore    Petrol       Manual      First      5   4.00    5  celerio
# 1066       Pune    Diesel       Manual      First      5   7.43    4   vitara
# 1067      Delhi    Diesel       Manual      First      5   2.75    9    swift
# 1068      Delhi    Diesel       Manual      First      5   4.75    6    swift
# 1069    Kolkata    Petrol       Manual      First      5   2.65    7    wagon
#
#       Mileage  Power  KM_Driven
# 1065     23.1  67.04         67
# 1066     24.3  88.50         37
# 1067     19.3  73.90         68
# 1068     28.4  74.00         27
# 1069     18.9  67.10         46

# %%
cars_df['Model'][0:5]
# Out:
# 0    ertiga
# 1     swift
# 2     swift
# 3      alto
# 4     wagon
# Name: Model, dtype: object

# %%
cars_df[['Model', 'Price']][0:5]
# Out:
#     Model  Price
# 0  ertiga   6.00
# 1   swift   5.60
# 2   swift   5.99
# 3    alto   2.75
# 4   wagon   1.85

# %% [markdown]
# ## 3. Sampling Records

# %%
cars_df.sample(5)
# Out:
#        Location Fuel_Type Transmission Owner_Type  Seats  Price  Age  Model  \
# 521     Chennai    Diesel       Manual      First      5   6.50    5  swift
# 943       Kochi    Petrol       Manual      First      5   3.69    5   alto
# 299       Kochi    Petrol       Manual      First      5   6.84    5   ciaz
# 886  Coimbatore    Petrol    Automatic      First      5   8.30    1  dzire
# 336       Delhi    Diesel       Manual      First      5   3.60    6   ritz
#
#      Mileage  Power  KM_Driven
# 521    25.20  74.00         23
# 943    24.07  67.10         37
# 299    20.73  91.10         46
# 886    22.00  81.80          8
# 336    23.20  73.94         32

# %% [markdown]
# # Univariate Analysis - Analyzing One Variable

# %% [markdown]
# ## 4. Transmission Types
#
# - What are different transmission types and how many cars are available from each transmission type (in percentages)?

# %%
cars_df.Transmission.value_counts()
# Out:
# Manual       976
# Automatic     94
# Name: Transmission, dtype: int64

# %%
cars_df.Transmission.value_counts(normalize=True)
# Out:
# Manual       0.91215
# Automatic    0.08785
# Name: Transmission, dtype: float64

# %% [markdown]
# ### Ex1. Participants Exercises:
#
# - What are different owner types?
# - What percentage of cars are available from each owner type for resale?

# %%
#TODO by participants
cars_df.Owner_Type.value_counts()
# Out:
# First             921
# Second            129
# Third              19
# Fourth & Above      1
# Name: Owner_Type, dtype: int64

# %%
cars_df.Owner_Type.value_counts(normalize=True)
# Out:
# First             0.860748
# Second            0.120561
# Third             0.017757
# Fourth & Above    0.000935
# Name: Owner_Type, dtype: float64

# %% [markdown]
# ## 5. Filtering Records
#
# - Find out how many cars were sold that were 15 years old or more?

# %%
old_cars_df = cars_df[cars_df.Age > 14]

# %%
old_cars_df.shape
# Out:
# (34, 11)

# %%
cars_df = cars_df[cars_df.Age < 15]

# %% [markdown]
# ## 6. Most and Least Expensive Cars

# %%
cars_df.sort_values('Price', ascending=False)[0:5]
# Out:
#         Location Fuel_Type Transmission Owner_Type  Seats  Price  Age   Model  \
# 873        Kochi    Diesel       Manual      First      5  10.19    2  vitara
# 629   Coimbatore    Diesel       Manual      First      5  10.15    2  vitara
# 343        Kochi    Petrol       Manual      First      5   9.96    2    ciaz
# 1051   Hyderabad    Petrol    Automatic      First      5   9.95    3    ciaz
# 24         Kochi    Petrol       Manual      First      5   9.90    2    ciaz
#
#       Mileage  Power  KM_Driven
# 873     24.30   88.5         57
# 629     24.30   88.5         52
# 343     20.73   91.1         15
# 1051    19.12   91.1         15
# 24      20.73   91.1         41

# %% [markdown]
# ### Ex2. Participants Exercises:
#
# - Find out top 10 least expensive cars sold in Bangalore and print only their names and sold price
#
#     - Apply filter
#     - Sort values
#     - Slice by column names
#     - Print only top 10 rows

# %%
cars_sold_bangalore=cars_df[cars_df.Location == 'Bangalore']
cars_sold_bangalore.sort_values('Price')['Model'][0:10]
# Out:
# 161      zen
# 837     alto
# 131    wagon
# 104     alto
# 475     alto
# 884    swift
# 63      alto
# 882    swift
# 861    swift
# 655     ritz
# Name: Model, dtype: object

# %% [markdown]
# #### Attempting the above in a single step

# %%
cars_sold_bangalore=cars_df[cars_df.Location == 'Bangalore'].sort_values('Price')['Model'][0:10]
cars_sold_bangalore
# Out:
# 161      zen
# 837     alto
# 131    wagon
# 104     alto
# 475     alto
# 884    swift
# 63      alto
# 882    swift
# 861    swift
# 655     ritz
# Name: Model, dtype: object

# %% [markdown]
# ## 7. Distribution of Resale Price
#
# - A distribution in statistics is a function that shows the possible values for a variable and how often they occur.
# - How many cars are sold at different price ranges? For example: cars sold in the price range of 1L - 2L, 2L - 3L etc.?

# %% [markdown]
# #### Histogram for plotting Continuous Variables (Price)

# %%
import matplotlib.pyplot as plt
import seaborn as sn

sn.set_style("whitegrid")
sn.set_context("paper")
sn.color_palette("Set2");

# %%
plt.figure(figsize=(12, 6))
plt.hist(cars_df.Price, bins = list(range(0, 11, 1)));
plt.xticks(list(range(0, 11, 1)))
plt.xlabel("Price")
plt.ylabel("Counts")
plt.title("Histogram of Resale Price");

# %%
plt.figure(figsize=(12, 6))
sn.kdeplot(data = cars_df,
          x = 'Price');

# %% [markdown]
# ### Ex3. Participants Exercises:
#
# - Draw a histogram for kilometer driven with each bin of size 10000km

# %%
cars_df.KM_Driven.min()
# Out:
# 0

# %%
cars_df.KM_Driven.max()
# Out:
# 168

# %%
plt.figure(figsize=(12, 6))
plt.hist(cars_df.KM_Driven, bins = list(range(0, 170, 10)));
plt.xticks(list(range(0, 170, 10)))
plt.xlabel("KM Driven")
plt.ylabel("Counts")
plt.title("Histogram of KM_Driven");

# %%
plt.figure(figsize=(12, 6))
sn.kdeplot(data = cars_df,
          x = 'KM_Driven');

# %% [markdown]
# ## 8. Outliers
#
# - In statistics, an outlier is a data point that differs significantly from other observations.
# - An outlier may be due to variability in the measurement or it may indicate experimental error; the latter are sometimes excluded from the data set.
# - An outlier can cause serious problems in statistical analyses.
#
# Source: https://en.wikipedia.org/wiki/Outlier
#
# ### 8.1 Using Standard Deviation Approach

# %%
from scipy import stats

# %%
stats.norm.interval(0.997,
                    cars_df.Price.mean(),
                    cars_df.Price.std())
# Out:
# (-2.0832498283884373, 11.131586276986535)

# %% [markdown]
# ### 8.2 Using Box Plot Approach

# %%
plt.figure(figsize=(12, 6))
sn.boxplot(data=cars_df.Price);

# %%
cars_df.Price.median()
# Out:
# 4.25

# %%
iqr = stats.iqr(cars_df.Price)
iqr
# Out:
# 3.1799999999999997

# %%
price_stats = cars_df.Price.describe()
price_stats
# Out:
# count    1070.000000
# mean        4.524168
# std         2.226416
# min         0.450000
# 25%         2.820000
# 50%         4.250000
# 75%         6.000000
# max        10.190000
# Name: Price, dtype: float64

# %%
min_price = price_stats['25%'] - 1.5 * iqr
min_price
# Out:
# -1.9499999999999993

# %%
max_price = price_stats['75%'] + 1.5 * iqr
max_price
# Out:
# 10.77

# %% [markdown]
# ### Ex4. Participants Exercise:
#
# - Find any outliers in terms of kilometer driven using both standard deviation and box plot approach?

# %%
stats.norm.interval(0.997,
                    cars_df.KM_Driven.mean(),
                    cars_df.KM_Driven.std())
# Out:
# (-36.041071949218875, 141.76817475295684)

# %% [markdown]
# #### Using Box Plot Approach

# %%
plt.figure(figsize=(12, 6))
sn.boxplot(data=cars_df.KM_Driven);

# %% [markdown]
# #### Using the IQR method to identify outliers

# %%
cars_df.KM_Driven.median()
# Out:
# 50.5

# %%
iqr = stats.iqr(cars_df.KM_Driven)
iqr
# Out:
# 38.0

# %%
km_driven_stats = cars_df.KM_Driven.describe()
km_driven_stats
# Out:
# count    1070.000000
# mean       52.863551
# std        29.957033
# min         0.000000
# 25%        31.000000
# 50%        50.500000
# 75%        69.000000
# max       168.000000
# Name: KM_Driven, dtype: float64

# %%
min_km_driven = km_driven_stats['25%'] - 1.5 * iqr
min_km_driven
# Out:
# -26.0

# %%
max_km_driven = km_driven_stats['75%'] + 1.5 * iqr
max_km_driven
# Out:
# 126.0

# %% [markdown]
# ## 9. Cars Models and their distribution
#
# We are assuming the first token to be the make and the second token to be the model.

# %%
cars_df.Model.value_counts()
# Out:
# swift      326
# alto       134
# wagon      125
# ertiga      70
# ciaz        66
# ritz        64
# baleno      61
# celerio     56
# vitara      35
# zen         27
# dzire       24
# omni        20
# a-star      17
# eeco        12
# 800         12
# sx4          9
# ignis        6
# s-cross      3
# esteem       2
# versa        1
# Name: Model, dtype: int64

# %% [markdown]
# ## 10. Top 10 selling models

# %%
models_df = cars_df.Model.value_counts().reset_index();
models_df
# Out:
#       index  Model
# 0     swift    326
# 1      alto    134
# 2     wagon    125
# 3    ertiga     70
# 4      ciaz     66
# 5      ritz     64
# 6    baleno     61
# 7   celerio     56
# 8    vitara     35
# 9       zen     27
# 10    dzire     24
# 11     omni     20
# 12   a-star     17
# 13     eeco     12
# 14      800     12
# 15      sx4      9
# 16    ignis      6
# 17  s-cross      3
# 18   esteem      2
# 19    versa      1

# %%
models_df.columns = ['Model', 'Counts']

# %%
models_df.head(5)
# Out:
#     Model  Counts
# 0   swift     326
# 1    alto     134
# 2   wagon     125
# 3  ertiga      70
# 4    ciaz      66

# %%
plt.figure(figsize=(15, 6));
sn.barplot(data = models_df,
          x = 'Model',
          y = 'Counts');

# %%
top10_models = list(models_df.Model)[0:10]
top10_models
# Out:
# ['swift',
#  'alto',
#  'wagon',
#  'ertiga',
#  'ciaz',
#  'ritz',
#  'baleno',
#  'celerio',
#  'vitara',
#  'zen']

# %% [markdown]
# ## 11. Models to Remove

# %%
models_to_remove = list(models_df[models_df.Counts < 10]['Model'])
models_to_remove
# Out:
# ['sx4', 'ignis', 's-cross', 'esteem', 'versa']

# %% [markdown]
# ### Ex6. Participants Exercise
#
# - Plot the number of cars sold for each of years of car edition (Year) using count plot.

# %% [markdown]
# #### There is no model year field in the data, plotting on the Age field

# %%
car_age_df = cars_df.Age.value_counts().reset_index();
car_age_df
# Out:
#     index  Age
# 0       4  169
# 1       5  138
# 2       6  134
# 3       3  120
# 4       8   90
# 5       7   87
# 6       2   65
# 7       9   61
# 8      10   56
# 9      11   33
# 10     12   28
# 11     13   20
# 12     14   18
# 13      1   17
# 14     16    9
# 15     17    7
# 16     15    7
# 17     18    6
# 18     22    2
# 19     20    2
# 20     21    1

# %%
car_age_df.columns = ['Age', 'Counts']
car_age_df.head(10)
# Out:
#    Age  Counts
# 0    4     169
# 1    5     138
# 2    6     134
# 3    3     120
# 4    8      90
# 5    7      87
# 6    2      65
# 7    9      61
# 8   10      56
# 9   11      33

# %%
plt.figure(figsize=(15, 6));
sn.barplot(data = car_age_df,
          x = 'Age',
          y = 'Counts');

# %%
top10_ages = list(car_age_df.Age)[0:10]
top10_ages
# Out:
# [4, 5, 6, 3, 8, 7, 2, 9, 10, 11]

# %% [markdown]
# #### Removing ages where sale < 10

# %%
ages_to_remove = list(car_age_df[car_age_df.Counts < 10]['Age'])
ages_to_remove
# Out:
# [16, 17, 15, 18, 22, 20, 21]

# %% [markdown]
# # Bivariate Analysis - Analyzing Two Variables

# %% [markdown]
# ## 12. Average selling prices of top 10 models

# %%
avg_price_models = cars_df.groupby('Model')['Price'].mean()
avg_price_models
# Out:
# Model
# 800        0.765833
# a-star     2.365294
# alto       2.519478
# baleno     6.855246
# celerio    4.118393
# ciaz       7.549545
# dzire      6.249167
# eeco       3.475000
# ertiga     6.920857
# esteem     1.100000
# ignis      6.148333
# omni       2.353000
# ritz       3.611250
# s-cross    7.950000
# swift      4.745215
# sx4        5.547778
# versa      1.250000
# vitara     8.713429
# wagon      2.796960
# zen        1.363333
# Name: Price, dtype: float64

# %% [markdown]
# ## 13. Distribution of Resale Price For Top 10 Models
#
# - What is distribution of sales price of cars of top 10 models, which are 2 years old?

# %%
plt.figure(figsize=(15, 6));
sn.boxplot(data = cars_df[cars_df.Model.isin(top10_models)],
          x = 'Model',
          y = 'Price',
          order = top10_models);

# %% [markdown]
# ### Ex7. Participant Exercise:
#
# - Find out the variations of sales prices for only SWIFT model for different ages (e.g. one year old, two year old and so on?

# %%
plt.figure(figsize=(15, 6));
sn.boxplot(data = cars_df[cars_df.Model == 'swift'],
          x = 'Age',
          y = 'Price');

# %% [markdown]
# ## 14. Demand for models across different locations

# %%
top10_cars_df = cars_df[cars_df.Model.isin(top10_models)]
models_by_locations = pd.crosstab(top10_cars_df.Location,
                                  top10_cars_df.Model,
                                 normalize='index');
models_by_locations
# Out:
# Model           alto    baleno   celerio      ciaz    ertiga      ritz  \
# Location
# Ahmedabad   0.093023  0.023256  0.046512  0.116279  0.116279  0.000000
# Bangalore   0.148148  0.000000  0.148148  0.037037  0.148148  0.037037
# Chennai     0.225000  0.050000  0.062500  0.050000  0.087500  0.025000
# Coimbatore  0.132353  0.117647  0.029412  0.102941  0.029412  0.132353
# Delhi       0.063830  0.117021  0.042553  0.085106  0.085106  0.021277
# Hyderabad   0.204225  0.042254  0.084507  0.035211  0.063380  0.147887
# Jaipur      0.147368  0.031579  0.021053  0.073684  0.042105  0.052632
# Kochi       0.136842  0.115789  0.052632  0.147368  0.042105  0.031579
# Kolkata     0.152381  0.028571  0.057143  0.028571  0.047619  0.066667
# Mumbai      0.080808  0.090909  0.060606  0.101010  0.111111  0.070707
# Pune        0.112069  0.043103  0.068966  0.017241  0.094828  0.060345
#
# Model          swift    vitara     wagon       zen
# Location
# Ahmedabad   0.372093  0.046512  0.162791  0.023256
# Bangalore   0.333333  0.037037  0.074074  0.037037
# Chennai     0.362500  0.012500  0.100000  0.025000
# Coimbatore  0.338235  0.058824  0.058824  0.000000
# Delhi       0.372340  0.042553  0.148936  0.021277
# Hyderabad   0.316901  0.021127  0.049296  0.035211
# Jaipur      0.389474  0.010526  0.178947  0.052632
# Kochi       0.252632  0.094737  0.105263  0.021053
# Kolkata     0.390476  0.019048  0.190476  0.019048
# Mumbai      0.262626  0.020202  0.161616  0.040404
# Pune        0.353448  0.051724  0.172414  0.025862

# %%
plt.figure(figsize=(15, 10));
sn.heatmap(models_by_locations,
          annot = True,
          fmt = '0.2f',
          cmap = 'YlGnBu')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Location'>

# %%
plt.figure(figsize=(12, 6));
sn.countplot(data = cars_df,
            x = 'Location',
            hue = 'Fuel_Type');

# %% [markdown]
# ### Ex8. Participants Exercise:
#
# - Find out the demand for differnent fuel type of cars for different models?

# %%
models_by_fueltype = pd.crosstab(top10_cars_df.Model,
                                  top10_cars_df.Fuel_Type,
                                 normalize='index');
models_by_fueltype
# Out:
# Fuel_Type    Diesel    Petrol
# Model
# alto       0.000000  1.000000
# baleno     0.213115  0.786885
# celerio    0.071429  0.928571
# ciaz       0.560606  0.439394
# ertiga     0.800000  0.200000
# ritz       0.640625  0.359375
# swift      0.644172  0.355828
# vitara     1.000000  0.000000
# wagon      0.000000  1.000000
# zen        0.000000  1.000000

# %%
plt.figure(figsize=(12, 6));
sn.heatmap(models_by_fueltype,
          annot = True,
          fmt = '0.2f',
          cmap = 'YlGnBu')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Model'>

# %%
plt.figure(figsize=(12, 6));
sn.countplot(data = cars_df,
            x = 'Model',
            hue = 'Fuel_Type');

# %% [markdown]
# ## 14. How mileage is effecting the resale price?

# %%
plt.figure(figsize=(12, 6));
sn.regplot(data = cars_df,
               x = 'Mileage',
               y = 'Price');

# %% [markdown]
# ## 15. How kilometer driven is effecting the resale price?

# %%
plt.figure(figsize=(12, 6));
sn.regplot(data = cars_df,
               x = 'KM_Driven',
               y = 'Price');

# %% [markdown]
# ### Ex9. Participants Exercise:
#
# - Find out the correlation between by drawing scatter plots
#     - Power and Price
#     - Age and Price

# %%
plt.figure(figsize=(12, 6));
sn.regplot(data = cars_df,
               x = 'Power',
               y = 'Price');

# %%
plt.figure(figsize=(12, 6));
sn.regplot(data = cars_df,
               x = 'Age',
               y = 'Price');

# %% [markdown]
# ## 16. Finding corrleation between multiple variables (numerical)

# %%
corr_mat = cars_df[['Price', 'Age', 'Power', 'Mileage', 'KM_Driven']].corr()
corr_mat
# Out:
#               Price       Age     Power   Mileage  KM_Driven
# Price      1.000000 -0.721158  0.645431  0.498633  -0.298655
# Age       -0.721158  1.000000 -0.316467 -0.516507   0.482101
# Power      0.645431 -0.316467  1.000000  0.129647  -0.008006
# Mileage    0.498633 -0.516507  0.129647  1.000000  -0.130217
# KM_Driven -0.298655  0.482101 -0.008006 -0.130217   1.000000

# %%
plt.figure(figsize=(10, 6));
sn.heatmap(corr_mat,
           annot = True,
           fmt = '0.2f',
           vmin = -1.0,
           vmax = 1.0,
           cmap = sn.diverging_palette(240,10));

# %% [markdown]
# ## 17. Save the DataFrame

# %%
final_cars_df = cars_df[~cars_df.Model.isin(models_to_remove)]

# %%
final_cars_df.shape
# Out:
# (1049, 11)

# %%
cars_df.shape
# Out:
# (1070, 11)

# %%
final_cars_df.to_csv('final_cars_maruti.csv', index = False)

# %%
final_cars_df.to_excel('final_cars_maruti.xlsx', index = False, sheet_name='maruti_sales')

# %% [markdown]
# ### Ex10. Participants Exercise:
#
# - Save the dataframe in excel format.

# %% [markdown]
# # Rules for plotting
#
# - Single Variable (Univariate Analysis)
#
#     - Continuous -> Histogram, boxplot, distribution plot
#     - Categorical -> Count Plot/Bar Plot
#
# - Two Variables (Bivariate Analysis)
#
#     - Continuous + Categorical -> Box plot, Overlapped Distribution Plot
#     - Continuous + Continuous -> Scatter Plot, heatmap
#     - Categoical + Categorical -> Bar Plot / Count Plot, heatmap
